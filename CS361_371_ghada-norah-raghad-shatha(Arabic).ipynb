# %% [markdown]
#                                          KINGDOM OF SAUDI ARABIA
#                                        Ministry of Higher Education
#                                        Al-Imam Mohammad University
#                                  College of Computer & Information Sciences
#
# ![unnamed.png](attachment:unnamed.png)
#
#                                     Artificial Intelligence (CS361)
#                                        Instructor: Amgad Al-amro
#                                        Ghada Al-Harbi(440021008)
#                                        Norah Al-Marul(440021196)
#                                        Raghad Al-Fares(440020499)
#                                        Shatha Al-Suwaid(440023707)

# %% [markdown]
# # الفهرس
#
#
# > ١. المقدمة
#
# > ٢. وصف مشكلة امونغ اس
#
# > ٢.١ هدف المشكلة
#
# > ٢.٢  مشكلة روبوت الطاقم في امونغ اس
#
# > ٢.٣ صياغة المشلكة
#
# > ٣. A* الشرح
#
# > ٣.١ A*حل مشكلة اومونغ اس باستخدام
#
# > ٤. الاستدلالات
#
# > ٤.١ الاستدلال المقبول
#
# > ٤.٢ الاستدلال الثاني
#
# > ٤.٣ الاستدلال الثالث
#
# > ٥. كيفية عمل الخوارزمية
#
# > ٦. A* تنفيذ خوارزمية
#
# > ٦.١ Node كلاس
#
# > ٦.٢ chlid كلاس
#
# > ٦.٣ relation كلاس
#
# > ٧. أساليب الاستدلال المختلفة غير المقبولة
#
# > ٧.١ قيم الاستدلال الأول
#
# > ٧.٢ قيم الاستدلال الثاني
#
# > ٨. الفرق بين الاستدلال
#
# > ٩. المراجع

# %% [markdown]
# # ١.المقدمة
#
# هذا المشروع يصف خوارزمية مع قيم استدلال مختلفة للتوصل الى الهدف في اقل تكلفة مسار

# %% [markdown]
# # ٢.وصف مشكلة امونغ اس
#
# امونغ اس هي لعبة مع مجموعة من اللاعبين حيث يكون واحد منهم محتال وقاتل، اعضاء الفريق عليهم ان يتمموا مهام حول الخريطة، اذا شك احد أعضاء الفريق في لاعب آخر يمكنه الابلاغ عنه عن طريق اجتماع في غرفة الكافيتيريا

# %% [markdown]
# ## ٢.١ هدف المشكلة
#
# اذا شك احد أعضاء الفريق في لاعب آخر يمكنه الابلاغ عنه عن طريق اجتماع في غرفة الكافتيريا ولذا علينا ان نجد اقصر طريق من غرفة المحرك السفلية إلى الكافيتريا

# %% [markdown]
# ## ٢.٢ مشكلة روبوت الطاقم في امونغ اس
#
# المشكلة هي عن روبوت من الطاقم الذي عليه ان يجد اقصر طريق لتبليغ عن لاعب شك به انه محتال او قاتل

# %% [markdown]
# ## ٢.٣صياغة المشلكة
#
# ![amongusMap.png](attachment:amongusMap.png)
#
# الحالة الابتدائية: روبوت الطاقم موجود في غرفة المحرك السفلية
#
# الإجراء:الروبوت الطاقم ينتقل من غرفة الى غرفة
#
# مساحة الحالة: الغرف والممرات
#
# اختبار الهدف: الروبوت يصل لغرفة الكافيتيريا للإبلاغ في اقصر طريق

# %% [markdown]
# ## A* ٣. الشرح
#
# إنها خوارزمية إيجاد المسار التي تحسب أقل تكلفة من البداية إلى الهدف وتعتمد على نتيجة F (n) = g (n) + h (n) لكل عقدة. تمثل G (n) التكلفة الفعلية من البداية إلى العقدة الحالية. تمثل H (n) التكلفة المقدرة من العقدة الحالية إلى الهدف.

# %% [markdown]
# ## A* ٣.١ حل مشكلة امونغ اس باستخدام
#
#
#
# العقدة: تمثل الغرف
#
# القوس: تمثل الممرات
#
# تكلفة قيم :افترضنا انها تمثل  عدد الممرات من العقدة الحالية الى الهدف
#
#  قيم الاستدلال :افترضنا انها تمثل باقي عدد الغرف التوي توصلنا للهدف
#
#   f(n)=g(n)+h(n) :f(n) عملية

# %% [markdown]
# ## *٤. الاستدلالات*
#
#  انشأنا قيم استدلالات  مختلفة لإظهار تأثير اختيار الاستدلال المقبول.

# %% [markdown]
# ##  ٤.١ الاستدلال المقبول
#
# هي مقبولة لأن التكلفة المتوقعة اقل من التكلفة الحقيقية. نحن نوافق على هذا الاستدلال لأنه يعطينا تكلفة حقيقية.
# ![h1.png](attachment:h1.png)

# %% [markdown]
# ## ٤. ٢ الاستدلال الثاني
#
#
#
# لقد غيرنا قيم الاستدلال لهذه الغرف
#
# (Upper_Engine=4, Reactor=3, Security=3) الى (Upper_Engine, Reactor, Security)
#
# حتى نحصل على تكلفة اكبر من تكلفة الاستدلال المقبولة. المسار هو
#
# Lower_Engine->Storage->Cafeteria.
#
# وتكلفة هذا المسار يساوي ٤
#
# ![h2.png](attachment:h2.png)

# %% [markdown]
# ## ٤.٣ الاستدلال الثالث
#
#
#
# لقد غيرنا قيم الاستدلال لهذه الغرف
#
# (Upper_Engine=5, Reactor=4, Security=4 ,Storage=3, Electrical=1) الى (Upper_Engine, Reactor, Security, Storage, Electrical)
#
# حتى نحصل على تكلفة اكبر من تكلفة الاستدلال المقبولة. المسار هو
#
# Lower_Engine->Electrical->Storage->Cafeteria.
#
# وتكلفة هذا المسار يساوي٧
#
# ![h3.png](attachment:h3.png)

# %% [markdown]
# ## ٥ كيفية عمل الخوارزمية
#
# هناك نوعان من القوائم
#
# أ. توسيع: قائمة لتخزين العقد التي تم فحصها.
#
# ب. هامش: إنها قائمة لتخزين العقد التي نريد فحصها.
#
# ٢. نبدأ العلم = صحيح و عداد = ١ ليحسب عدد العقد-الغرف
#
# ٣. استخدمنا حلقة تكرار، وسوف يتم تكرارها حتى يصبح العلم خاطئًا
#
# ٤. نضع القيمة الأولى في الهامش ونخزنها في العقدة
#
# ٥. ثم نضيف (عقدة) لتوسيع القائمة
#
# ٦. نتحقق من اسم العقدة إذا كان يساوي عقدة الوجهة (الكافتيريا). ثم قمنا بتغيير
#
# قيمة العلم إلى خطأ ونقوم بإيقاف حلقة التكرار لإيقاف البحث
#
# ٧ ثم يرجع لحلقة التكرار لاكتشاف أبناء العقدة
#
# ٧.١ ثم أضف الطفل مع العقدة والتكلفة بينهما إلى قائمة الهامش. ثم عد إلى الخطوة ٧
# ٨. بعد ذلك أرسل قائمة الهامش إلى
#
#  sortfring(fringe)
#
# :٩. أخيرًا ، أرسل توسيع القائمة إلى
#
# pathAstr (expand)

# %%
counter = 1
def AStar():
    global counter
    expand = []# initialize axpand list
    fringe=[]# intialize fringe list
    fringe.append(source)# add the source node fringe
    flag = True
    while flag:
        node = fringe.pop(0)
        expand.append(node)
        if node.getname() == destination.getname():
            flag = False
            break
        for i in node.getchild():
            fringe.append(relation(i, node, i.cost))
            counter = counter+1
        sortfring(fringe) 
    pathAstr(expand)#to find the correct path

# %% [markdown]
# # A* ٦. تنفيذ خوارزمية
#
#
# ## Node ٦.١ إنشاء كلاس
#
#
# نقوم بإنشاء فئة العقدة لبدء العقدة (الغرفة) مع قيم الاستدلال  ، نضيف الإبن ، ونحصل على اسم العقدة وتوابعها ، نحسب عملية الخوارزمية والغرف المجاورة لها

# %%
class Node():#to represent rooms
    def __init__(self, name, h):
        self.name = name
        self.h = h
        self.child = []
        self.parent = []
        self.cost = 0
          
    def getchild(self,i):#return a specific adjecent room
        return self.child[i]
    
    def getname(self):
        return str(self.name)

    def addchild(self, child):#add adjacent
        self.child.append(child)

    def getchild(self):#return all adjacent
        return self.child

    def evaluate_fun(self):#the evaluation function 
        return 0 + self.h
    
    def leng(self):#return the number of adjacent rooms
        return len(self.child)

# %% [markdown]
# ## chlid ٦.٢ ننشأ كلاس
# لإضافة مصفوفة من الابناء حيث انهم يعتبرون غرف مجاورة
#  chlid ننشأ كلاس

# %%
class child():#each room will have an array of child which are all adjacent room 
    def __init__(self, name, parent, cost, h):#constructor
        self.name = name
        self.cost = cost
        self.h = h

    def getname(self):
        return self.name.getname()

    def evaluate_fun(self):
        return self.cost + self.h
    
    def getchild(self,i):#return specific adjacent room
        return self.name.child[i]
    
    def getchild(self):#return all adjacent rooms
        return self.name.getchild()

    def getparent(self):#return the previuos rooms the crew member visit
        return self.name.getparent()
    
    def leng(self):#the number of adjacent rooms
        return len(self.name.child)

# %% [markdown]
# ## relation ٦.٣ ننشأ كلاس
# لاستعادة عملية حساب الخوارزمية للغرف التي تمت زيارتها relation ٦.٣ ثم انشأنا كلاس

# %%
class relation():#this class is used to retrieve the path of visited rooms 
    def __init__(self, name, parent, cost):
        self.name = name
        self.cost = cost
        self.parent = parent

    def function(self):
        return self.name.h + self.cost
    
    def getchild(self):
        return self.name.getchild()

    def getname(self):
        return self.name.getname()

# %% [markdown]
#  اعطاء كل غرفة قيمة استدلال

# %%
#create object of each room heuristic_1 
Lower_Engine = Node('Lower_Engine', 4)
Upper_Engine = Node('Upper_Engine', 1)
Reactor = Node('Reactor', 2)
Security = Node('Security', 2)
Medbay = Node('Medbay', 1)
Electrical= Node('Electrical', 2)
Storage = Node('Storage', 1)
Admin = Node('Admin', 1)
Communication = Node('Communication', 3)
O2 = Node('O2', 2)
Shields = Node('Shields', 2)
Weapons = Node('Weapons', 1)
Navigation = Node('Navigation', 2)
Cafeteria = Node('Cafeteria', 0)

# %% [markdown]
# ربط كل غرفة بالغرف المجاورة لها

# %%
#add Lower_Engine adjacents
Lower_Engine.addchild(child(Upper_Engine,Lower_Engine, 1,1))
Lower_Engine.addchild(child(Reactor,Lower_Engine, 2,2))
Lower_Engine.addchild(child(Security, Lower_Engine,2,2))
Lower_Engine.addchild(child(Electrical, Lower_Engine,4,2))
Lower_Engine.addchild(child(Storage, Lower_Engine,3,1))
#add Upper_Engine adjacent
Upper_Engine.addchild(child(Cafeteria,Upper_Engine,1,0))
Upper_Engine.addchild(child(Medbay,Upper_Engine,2,1))
#add Reactor adjacent
Reactor.addchild(child(Security,Reactor,1,2))
Reactor.addchild(child(Upper_Engine,Reactor,2,1))
#add Security adjacent
Security.addchild(child(Upper_Engine, Security,2,1))
#add Medbay adjacent
Medbay.addchild(child(Cafeteria, Medbay,2,0))
#add Electrical adjacent
Electrical.addchild(child(Storage, Electrical,2,1))
# add Storage adjacent
Storage.addchild(child(Cafeteria,Storage, 1,0))
Storage.addchild(child(Admin,Storage, 2,1))
Storage.addchild(child(Communication, Storage,2,3))
Storage.addchild(child(Shields, Storage,1,2))
# add Admin adjacent 
Admin.addchild(child(Cafeteria, Admin,2,0))
# add Communication adjacent 
Communication.addchild(child(Shields, Communication,2,2))
# add O2 adjacent 
O2.addchild(child(Shields, O2,4,2))
O2.addchild(child(Weapons, O2,2,1))
O2.addchild(child(Navigation, O2,2,2))
# add Shields adjacent
Shields.addchild(child(Navigation, Shields,4,2))
Shields.addchild(child(Weapons, Shields,5,1))
# add Weapons adjacent 
Weapons.addchild(child(Navigation, Weapons,4,2))
Weapons.addchild(child(Cafeteria, Weapons,1,0))
# add Navigation adjacent 
Navigation.addchild(child(Shields, Navigation,4,2))
Navigation.addchild(child(Weapons, Navigation,4,1))
Navigation.addchild(child(O2, Navigation,3,2))

# %% [markdown]
#  هي الغرفة التي نبدأ منها حيث ان طاقم الفريق سيكونون فيها Node التي من نوع source
#
# دائماً ستكون الهدف Node التي من نوع  destination و

# %%
source = Lower_Engine
destination = Cafeteria

# %% [markdown]
# relation في كلاس function هذه الميثود ستأخذ جميع عقد الابناء وترتبهم تنازلياً بناءاً على ميثود  sortfring(fringe)

# %%
def sortfring(fringe):# bubble sort to sort the fringe in decreasing order
    swapped = True
    while swapped:
        swapped = False
        for i in range(len(fringe) - 1):
            if fringe[i].function() > fringe[i + 1].function():
                fringe[i], fringe[i + 1] = fringe[i + 1], fringe[i]
                swapped = True

# %% [markdown]
# ستأخذ قائمة التوسع وتتحقق من ابناء كل عنصر في قائمة التوسع بعدها يتم طباعة المسار والتكلفة pathAstr(expand) ميثود
#
#
#  o(node) افترضنا أن تعقيد الفضاء هو عدد العقد الموسعة

# %%
def pathAstr(expand):#backtracking to find the path
    expand.reverse()
    pathA = []
    counter = 1
    pathA.append(expand[0])
    flage=True
    while flage:
        if len(expand)<=1:
            break
        current=expand[0].parent
        if current.getname()== expand[1].getname():
            pathA.append(current)
            expand.pop(0)
            counter = counter +1
        else:
            expand.pop(1)
            pathA.reverse()   
    costA=0
    path = []
    for i in pathA:
        costA+=i.cost
        path.append(i.getname())
    path.reverse()
    print('Path: {}'.format(path))
    print('cost = ', costA)
    print('space complexity= ', counter)

# %% [markdown]
# لإيجاد المسار AStar() ابدأ المؤقت لحساب تعقيد الوقت ثم استدعي ميثود

# %%
start = time.time()
AStar() #call A star
end = time.time()
time_n = end - start 
print('time complexity= ',time_n)
print('space complexity= ', counter)

# %% [markdown]
# استخدمنا الاستيراد حتى نتمكن من حساب التعقيد الزمني .

# %%
import time

# %% [markdown]
# # ٧. أساليب الاستدلال المختلفة غير المقبولة

# %% [markdown]
# ## ٧.١ قيم الاستدلال الثاني

# %%
#create object of each room seconed heuristic_2 
Lower_Engine = Node('Lower_Engine', 4)
Upper_Engine = Node('Upper_Engine', 4)
Reactor = Node('Reactor', 3)
Security = Node('Security', 3)
Medbay = Node('Medbay', 1)
Electrical= Node('Electrical', 2)
Storage = Node('Storage', 1)
Admin = Node('Admin', 1)
Communication = Node('Communication', 3)
O2 = Node('O2', 2)
Shields = Node('Shields', 2)
Weapons = Node('Weapons', 1)
Navigation = Node('Navigation', 2)
Cafeteria = Node('Cafeteria', 0)

#add Lower_Engine adjacents
Lower_Engine.addchild(child(Upper_Engine,Lower_Engine, 1,4))
Lower_Engine.addchild(child(Reactor,Lower_Engine, 2,3))
Lower_Engine.addchild(child(Security, Lower_Engine,2,3))
Lower_Engine.addchild(child(Electrical, Lower_Engine,4,2))
Lower_Engine.addchild(child(Storage, Lower_Engine,3,1))
#add Upper_Engine adjacent
Upper_Engine.addchild(child(Cafeteria,Upper_Engine,1,0))
Upper_Engine.addchild(child(Medbay,Upper_Engine,2,1))
#add Reactor adjacent
Reactor.addchild(child(Security,Reactor,1,3))
Reactor.addchild(child(Upper_Engine,Reactor,2,4))
#add Security adjacent
Security.addchild(child(Upper_Engine, Security,2,4))
#add Medbay adjacent
Medbay.addchild(child(Cafeteria, Medbay,2,0))
#add Electrical adjacent
Electrical.addchild(child(Storage, Electrical,2,1))
# add Storage adjacent
Storage.addchild(child(Cafeteria,Storage, 1,0))
Storage.addchild(child(Admin,Storage, 2,1))
Storage.addchild(child(Communication, Storage,2,3))
Storage.addchild(child(Shields, Storage,1,2))
# add Admin adjacent 
Admin.addchild(child(Cafeteria, Admin,2,0))
# add Communication adjacent 
Communication.addchild(child(Shields, Communication,2,2))
# add O2 adjacent 
O2.addchild(child(Shields, O2,4,2))
O2.addchild(child(Weapons, O2,2,1))
O2.addchild(child(Navigation, O2,2,2))
# add Shields adjacent
Shields.addchild(child(Navigation, Shields,4,2))
Shields.addchild(child(Weapons, Shields,5,1))
# add Weapons adjacent 
Weapons.addchild(child(Navigation, Weapons,4,2))
Weapons.addchild(child(Cafeteria, Weapons,1,0))
# add Navigation adjacent 
Navigation.addchild(child(Shields, Navigation,4,2))
Navigation.addchild(child(Weapons, Navigation,4,1))
Navigation.addchild(child(O2, Navigation,3,2))

# %% [markdown]
# ## ٧.٢ قيم الاستدلال الثالث

# %%
#create object of each room seconed heuristic_3
Lower_Engine = Node('Lower_Engine', 4)
Upper_Engine = Node('Upper_Engine', 5)
Reactor = Node('Reactor', 4)
Security = Node('Security', 4)
Medbay = Node('Medbay', 1)
Electrical= Node('Electrical', 1)
Storage = Node('Storage', 3)
Admin = Node('Admin', 1)
Communication = Node('Communication', 3)
O2 = Node('O2', 2)
Shields = Node('Shields', 2)
Weapons = Node('Weapons', 1)
Navigation = Node('Navigation', 2)
Cafeteria = Node('Cafeteria', 0)

#add Lower_Engine adjacents
Lower_Engine.addchild(child(Upper_Engine,Lower_Engine, 1,5))
Lower_Engine.addchild(child(Reactor,Lower_Engine, 2,4))
Lower_Engine.addchild(child(Security, Lower_Engine,2,4))
Lower_Engine.addchild(child(Electrical, Lower_Engine,4,1))
Lower_Engine.addchild(child(Storage, Lower_Engine,3,3))
#add Upper_Engine adjacent
Upper_Engine.addchild(child(Cafeteria,Upper_Engine,1,0))
Upper_Engine.addchild(child(Medbay,Upper_Engine,2,1))
#add Reactor adjacent
Reactor.addchild(child(Security,Reactor,1,4))
Reactor.addchild(child(Upper_Engine,Reactor,2,5))
#add Security adjacent
Security.addchild(child(Upper_Engine, Security,2,5))
#add Medbay adjacent
Medbay.addchild(child(Cafeteria, Medbay,2,0))
#add Electrical adjacent
Electrical.addchild(child(Storage, Electrical,2,3))
# add Storage adjacent
Storage.addchild(child(Cafeteria,Storage, 1,0))
Storage.addchild(child(Admin,Storage, 2,1))
Storage.addchild(child(Communication, Storage,2,3))
Storage.addchild(child(Shields, Storage,1,2))
# add Admin adjacent 
Admin.addchild(child(Cafeteria, Admin,2,0))
# add Communication adjacent 
Communication.addchild(child(Shields, Communication,2,2))
# add O2 adjacent 
O2.addchild(child(Shields, O2,4,2))
O2.addchild(child(Weapons, O2,2,1))
O2.addchild(child(Navigation, O2,2,2))
# add Shields adjacent
Shields.addchild(child(Navigation, Shields,4,2))
Shields.addchild(child(Weapons, Shields,5,1))
# add Weapons adjacent 
Weapons.addchild(child(Navigation, Weapons,4,2))
Weapons.addchild(child(Cafeteria, Weapons,1,0))
# add Navigation adjacent 
Navigation.addchild(child(Shields, Navigation,4,2))
Navigation.addchild(child(Weapons, Navigation,4,1))
Navigation.addchild(child(O2, Navigation,3,2))

# %% [markdown]
# # ٨. الفرق بين الاستدلال
#
# لاحظنا أن الأساليب التجريبية المختلفة تعطي تكلفة مختلفة وتعقيدًا زمنيًا وتعقيدًا للمكانيًا.
#
# يعطي الاستدلال المقبول (Heuristic_1) أقل تكلفة وتعقيد زمني وتعقيد المكان.

# %% [markdown]
# ![Screen%20Shot%202021-12-11%20at%2018.59.08.png](attachment:Screen%20Shot%202021-12-11%20at%2018.59.08.png)

# %% [markdown]
# # ٩. المراجع
#
# #### ١.طريقة تحميل جيبتر؟
# https://www.youtube.com/watch?v=syijLJ3oQzU
#
# #### ٢.  تعليم لغة البايثون
# https://www.youtube.com/playlist?list=PLF8OvnCBlEY1j4hxoqXqJk08ASU7D_W87
#
# #### ٣. مصدر الكود
# https://colab.research.google.com/drive/1m06GIpkElZseJv-NGwyJgPRtEOQECVyD
#
# #### ٤. طريقة حساب التعقيد الزمني
# https://www.mygreatlearning.com/blog/why-is-time-complexity-essential/
